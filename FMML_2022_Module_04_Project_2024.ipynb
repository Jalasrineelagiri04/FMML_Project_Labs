# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalasrineelagiri04/FMML_Project_Labs/blob/main/FMML_2022_Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = ## [REQUIRED]
    new_x = ## [REQUIRED]

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append## [REQUIRED])

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
#   File "<ipython-input-41-00154aa77ab8>", line 20
#     gradient = ## [REQUIRED]
#                ^
# SyntaxError: invalid syntax

# %%
#TASK 1
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Compute the gradient (df/dx) at the current x value
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED] Update x using the gradient and the step_multiplier

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Compute and append the slope at the new x value

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
#TASK 2
# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**2  # [REQUIRED] Define the function g(x)

def dg(x):
    return 2 * x  # [REQUIRED] Define the derivative of g(x), dg(x)

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
import matplotlib.pyplot as plt

# Make some data
x_2 = np.linspace(-2, 2, 1000)

# Function g(x) and its derivative dg(x)
y_g = g(x_2)
y_dg = dg(x_2)

# Plotting g(x)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.title('Function g(x)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plotting dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, y_dg, color='orange', label="g'(x) = 2x")
plt.title("Derivative dg(x)")
plt.xlabel('x')
plt.ylabel("dg(x)")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.0234052067759206
# Number of steps: 76

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.004894871981406463
# Number of steps: 230

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -0.023960349927139895
# Number of steps: 36

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 :Code the same things as they were done for  the first two examples
import numpy as np
import matplotlib.pyplot as plt

# Function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2 * x

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
g_values = [g(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = dg(previous_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    g_values.append(g(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

# Plotting g(x) and its derivative dg(x) during gradient descent
plt.figure(figsize=(12, 4))

# Plotting g(x)
plt.subplot(1, 2, 1)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.scatter(x_list, g_values, color='red', label='Gradient Descent')
plt.title('Function g(x) and Gradient Descent')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plotting dg(x)
plt.subplot(1, 2, 2)
plt.plot(x_2, y_dg, color='orange', label="g'(x) = 2x")
plt.title("Derivative dg(x)")
plt.xlabel('x')
plt.ylabel("dg(x)")
plt.legend()

plt.tight_layout()
plt.show()

print('Local minimum occurs at:', new_x)
print('g(x) value at this point is:', g(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: 3.425394462494306e-05
# g(x) value at this point is: 1.1733327223686654e-09

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  109

# %%
## TASK-5 : Run gradient descent 3 times
## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
                                                multiplier=0.0005, precision=0.0001, max_iter=n)


mid_gamma =## [REQUIRED]
high_gamma =## [REQUIRED]

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)

# %%
#TASK 5
import numpy as np
import matplotlib.pyplot as plt

# Function g(x) and its derivative dg(x)
def g(x):
    return x**2

def dg(x):
    return 2 * x

# Function for gradient descent
def gradient_descent(initial_x, step_multiplier, precision, max_iterations=500):
    x_list = [initial_x]
    g_values = [g(initial_x)]

    for n in range(max_iterations):
        previous_x = x_list[-1]
        gradient = dg(previous_x)
        new_x = previous_x - step_multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        g_values.append(g(new_x))

        if step_size < precision:
            print(f'Convergence achieved after {n} iterations')
            break

    return x_list, g_values, new_x

# Run gradient descent three times with different initial points
initial_x_values = [3, -2, 1.5]
step_multiplier = 0.1
precision = 0.00001

plt.figure(figsize=(18, 4))

for i, initial_x in enumerate(initial_x_values):
    x_list, g_values, local_min = gradient_descent(initial_x, step_multiplier, precision)

    # Plotting g(x) and its derivative dg(x) during gradient descent
    plt.subplot(1, 3, i+1)
    plt.plot(x_2, y_g, label='g(x) = x^2')
    plt.scatter(x_list, g_values, color='red', label='Gradient Descent')
    plt.title(f'Gradient Descent from {initial_x}')
    plt.xlabel('x')
    plt.ylabel('g(x)')
    plt.legend()

    print(f'Local minimum from initial x={initial_x} occurs at x={local_min} with g(x)={g(local_min)}')

plt.tight_layout()
plt.show()
# Out:
# Convergence achieved after 50 iterations
# Local minimum from initial x=3 occurs at x=3.425394462494306e-05 with g(x)=1.1733327223686654e-09
# Convergence achieved after 48 iterations
# Local minimum from initial x=-2 occurs at x=-3.568119231764901e-05 with g(x)=1.2731474852090546e-09
# Convergence achieved after 47 iterations
# Local minimum from initial x=1.5 occurs at x=3.3451117797795954e-05 with g(x)=1.1189772819220212e-09

# %%
# Function for gradient descent
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=100):
    x_list = [initial_guess]
    slope_list = [derivative_func(initial_guess)]

    for n in range(max_iter):
        previous_x = x_list[-1]
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            print(f'Convergence achieved after {n} iterations')
            break

    return x_list, slope_list, new_x

# Run gradient descent with different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the learning rate experiments
plt.figure(figsize=(18, 4))

# Plotting low_gamma
plt.subplot(1, 4, 1)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.scatter(low_gamma[0], low_gamma[1], color='red', label='Gradient Descent')
plt.title('Low Learning Rate (0.0005)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plotting mid_gamma
plt.subplot(1, 4, 2)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.scatter(mid_gamma[0], mid_gamma[1], color='red', label='Gradient Descent')
plt.title('Mid Learning Rate (0.001)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plotting high_gamma
plt.subplot(1, 4, 3)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.scatter(high_gamma[0], high_gamma[1], color='red', label='Gradient Descent')
plt.title('High Learning Rate (0.002)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

# Plotting insane_gamma
plt.subplot(1, 4, 4)
plt.plot(x_2, y_g, label='g(x) = x^2')
plt.scatter(insane_gamma[0], insane_gamma[1], color='red', label='Gradient Descent')
plt.title('Insane Learning Rate (0.25)')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Convergence achieved after 14 iterations

# %%
## TASK-7 : Plot reduction in cost for each iteration
# Function for gradient descent
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=100):
    x_list = [initial_guess]
    cost_list = [g(initial_guess)]

    for n in range(max_iter):
        previous_x = x_list[-1]
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        cost_list.append(g(new_x))

        if step_size < precision:
            print(f'Convergence achieved after {n} iterations')
            break

    return x_list, cost_list, new_x

# Run gradient descent with different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the reduction in cost for each iteration
plt.figure(figsize=(18, 4))

# Plotting low_gamma
plt.subplot(1, 4, 1)
plt.plot(range(len(low_gamma[1])), low_gamma[1], label='Cost Reduction')
plt.title('Low Learning Rate (0.0005)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting mid_gamma
plt.subplot(1, 4, 2)
plt.plot(range(len(mid_gamma[1])), mid_gamma[1], label='Cost Reduction')
plt.title('Mid Learning Rate (0.001)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting high_gamma
plt.subplot(1, 4, 3)
plt.plot(range(len(high_gamma[1])), high_gamma[1], label='Cost Reduction')
plt.title('High Learning Rate (0.002)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting insane_gamma
plt.subplot(1, 4, 4)
plt.plot(range(len(insane_gamma[1])), insane_gamma[1], label='Cost Reduction')
plt.title('Insane Learning Rate (0.25)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Convergence achieved after 14 iterations

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples
# Function for gradient descent
def gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter=100):
    x_list = [initial_guess]
    cost_list = [g(initial_guess)]

    for n in range(max_iter):
        previous_x = x_list[-1]
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        cost_list.append(g(new_x))

        if step_size < precision:
            print(f'Convergence achieved after {n} iterations')
            break

    return x_list, cost_list, new_x

# Run gradient descent with different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting the reduction in cost for each iteration
plt.figure(figsize=(18, 4))

# Plotting low_gamma
plt.subplot(1, 4, 1)
plt.plot(range(len(low_gamma[1])), low_gamma[1], label='Cost Reduction')
plt.title('Low Learning Rate (0.0005)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting mid_gamma
plt.subplot(1, 4, 2)
plt.plot(range(len(mid_gamma[1])), mid_gamma[1], label='Cost Reduction')
plt.title('Mid Learning Rate (0.001)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting high_gamma
plt.subplot(1, 4, 3)
plt.plot(range(len(high_gamma[1])), high_gamma[1], label='Cost Reduction')
plt.title('High Learning Rate (0.002)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

# Plotting insane_gamma
plt.subplot(1, 4, 4)
plt.plot(range(len(insane_gamma[1])), insane_gamma[1], label='Cost Reduction')
plt.title('Insane Learning Rate (0.25)')
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Convergence achieved after 14 iterations

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Define your function f(x, y)
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate data
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)

# Create a 3D plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

# Set labels
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.4)

# Show the plot
plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
from sympy import symbols, diff, sin, sqrt

# Define symbols
a, b = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Display the cost function
print('Our cost function f(x, y) is:', f(a, b))

# Compute the partial derivative with respect to x
partial_derivative_x = diff(f(a, b), a)
print('Partial derivative wrt x is:', partial_derivative_x)

# Evaluate the cost function at x=1.8, y=1.0
value_at_point = f(a, b).evalf(subs={a: 1.8, b: 1.0})
print('Value of f(x, y) at x=1.8, y=1.0 is:', value_at_point)

# Evaluate the partial derivative with respect to x at x=1.8, y=1.0
partial_derivative_value = partial_derivative_x.evalf(subs={a: 1.8, b: 1.0})
print('Value of partial derivative wrt x:', partial_derivative_value)
# Out:
# Our cost function f(x, y) is: sin(sqrt(x**2 + y**2))
# Partial derivative wrt x is: x*cos(sqrt(x**2 + y**2))/sqrt(x**2 + y**2)
# Value of f(x, y) at x=1.8, y=1.0 is: 0.883117713196773
# Value of partial derivative wrt x: -0.410112173744750

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [-3.81217567902896e-15 -2.11787537723831e-15]
# Minimum occurs at x value of:  4.11936911511823
# Minimum occurs at y value of:  2.28853839728790
# The cost is:  -1.00000000000000

# %%
##########################
##########################

## TASK-10 :
from sympy import symbols, diff, sin, sqrt

# Define symbols
x, y = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Partial derivative functions
def fpx(x, y):
    return diff(f(x, y), x)

def fpy(x, y):
    return diff(f(x, y), y)

# Example usage
x_val = 1.8
y_val = 1.0

# Create symbolic variables for x and y
x_sym = symbols('x')
y_sym = symbols('y')

# Evaluate the partial derivatives at the point (x=1.8, y=1.0)
partial_derivative_x_value = fpx(x_sym, y_sym).evalf(subs={x_sym: x_val, y_sym: y_val})
partial_derivative_y_value = fpy(x_sym, y_sym).evalf(subs={x_sym: x_val, y_sym: y_val})

print('Partial derivative wrt x at x=1.8, y=1.0:', partial_derivative_x_value)
print('Partial derivative wrt y at x=1.8, y=1.0:', partial_derivative_y_value)
# Out:
# Partial derivative wrt x at x=1.8, y=1.0: -0.410112173744750
# Partial derivative wrt y at x=1.8, y=1.0: -0.227840096524861

# %%
# Setup
import numpy as np
from sympy import symbols, diff, sin, sqrt, lambdify

# Define symbols
x, y = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Partial derivative functions
def fpx(x, y):
    return diff(f(x, y), x)

def fpy(x, y):
    return diff(f(x, y), y)

# Convert symbolic expressions to callable functions
fpx_func = lambdify((x, y), fpx(x, y), 'numpy')
fpy_func = lambdify((x, y), fpy(x, y), 'numpy')

# Gradient Descent
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

for n in range(max_iter):
    gradient_x = fpx_func(params[0], params[1])
    gradient_y = fpy_func(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array: [-3.26621060e-15 -1.81456144e-15]
# Minimum occurs at x value of:  4.119369115118229
# Minimum occurs at y value of:  2.2885383972879025
# The cost is:  -1.00000000000000

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
import numpy as np
from sympy import symbols, diff, sin, sqrt, lambdify

# Define symbols
x, y = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Convert symbolic expressions to callable functions
fpx_func = lambdify((x, y), fpx(x, y), 'numpy')
fpy_func = lambdify((x, y), fpy(x, y), 'numpy')

# Gradient Descent
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0])  # initial guess
values_array = np.zeros((max_iter + 1, 2))  # Preallocate array
values_array[0, :] = params  # Store initial guess

for n in range(max_iter):
    gradient_x = fpx_func(params[0], params[1])
    gradient_y = fpy_func(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array[n + 1, :] = params  # Store updated parameters

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [-6.41083832e-09 -3.56157684e-09]
# Minimum occurs at x value of: 4.119369109348478
# Minimum occurs at y value of: 2.2885383940824857
# The cost is: -1.00000000000000

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from sympy import symbols, sin, sqrt, lambdify

# Define symbols
x, y = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return sin(sqrt(x**2 + y**2))

# Convert symbolic expression to callable function
f_func = lambdify((x, y), f(x, y), 'numpy')

# Generate data for the surface plot
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f_func(x_4, y_4)

# Gradient Descent
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0])  # initial guess
values_array = np.zeros((max_iter + 1, 2))
values_array[0, :] = params

for n in range(max_iter):
    gradient_x = fpx_func(params[0], params[1])
    gradient_y = fpy_func(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_array[n + 1, :] = params

# Create a 3D plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
ax.plot_surface(x_4, y_4, z_4, cmap=cm.coolwarm, alpha=0.4)

# Plot the trajectory
ax.scatter(values_array[:, 0], values_array[:, 1],
           f_func(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Assuming x_5 and y_5 are NumPy arrays
x_5 = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Example data for x
y_5 = np.array([2, 4, 5, 4, 5])  # Example data for y

# Create and fit the linear regression model
regr = LinearRegression()
regr.fit(x_5, y_5)

# Print the coefficients
print('Theta 0 (intercept):', regr.intercept_)
print('Theta 1 (slope):', regr.coef_[0])

# Predictions
x_new = np.array([6, 7, 8]).reshape(-1, 1)  # New data for prediction
y_pred = regr.predict(x_new)
print('Predicted y values:', y_pred)
# Out:
# Theta 0 (intercept): 2.2
# Theta 1 (slope): 0.6
# Predicted y values: [5.8 6.4 7. ]

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[2.07026161]
#  [3.29298808]
#  [4.51571454]
#  [5.738441  ]
#  [6.96116747]]
# In comparison, the actual y values are
#  [2 4 5 4 5]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above
import numpy as np

def mse(y, y_hat):
    return np.mean((y - y_hat)**2)

# Assuming y and y_hat are NumPy arrays
y = np.array([2, 4, 5, 4, 5])  # Actual values
y_hat = regr.predict(x_5)  # Predicted values using the linear regression model

# Calculate and print the MSE
mse_value = mse(y, y_hat)
print('Mean Squared Error (MSE):', mse_value)
# Out:
# Mean Squared Error (MSE): 0.47999999999999987

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

def mse(y, y_hat):
    return np.mean((y - y_hat)**2)

# Assuming x_5 and y_5 are NumPy arrays
x_5 = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Example data for x
y_5 = np.array([2, 4, 5, 4, 5])  # Example data for y

# Assuming you have a linear regression model already trained
regr = LinearRegression()
regr.fit(x_5, y_5)
y_hat = regr.predict(x_5)

# Calculate and print the MSE using the custom mse function
manual_mse = mse(y_5, y_hat)
print('Manually calculated MSE is:', manual_mse)

# Calculate and print the MSE using scikit-learn's mean_squared_error
mse_scikit = mean_squared_error(y_5, y_hat)
print('MSE regression using manual calc is', mse_scikit)

# Calculate and print the MSE using scikit-learn with regr.predict(x_5)
mse_regr = mean_squared_error(y_5, regr.predict(x_5))
print('MSE regression is', mse_regr)
# Out:
# Manually calculated MSE is: 0.47999999999999987
# MSE regression using manual calc is 0.47999999999999987
# MSE regression is 0.47999999999999987

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 1.3822681245423096
# Min occurs at (i,j): (63, 199)
# Min MSE for Theta 0 at plot_t0[111][91] 3.0
# Min MSE for Theta 1 at plot_t1[111][91] 0.2663316582914572

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
import numpy as np

# Assuming x_5 and y_5 are NumPy arrays
x_5 = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Example data for x
y_5 = np.array([2, 4, 5, 4, 5])  # Example data for y

# Function to calculate gradient
def grad(x, y, thetas):
    n = len(y)
    gradient = np.zeros(2)
    gradient[0] = (-2/n) * np.sum(y - (thetas[0] + thetas[1] * x))
    gradient[1] = (-2/n) * np.sum((y - (thetas[0] + thetas[1] * x)) * x[:, 0])
    return gradient

# Function to calculate MSE
def mse(y, y_hat):
    return np.mean((y - y_hat)**2)

# Gradient Descent
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: -33.82400000000059
# Min occurs at Theta 1: 12.728000000000195
# MSE is: 325.3335680000099

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
