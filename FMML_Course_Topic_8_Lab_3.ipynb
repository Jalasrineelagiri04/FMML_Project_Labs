# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalasrineelagiri04/FMML_Project_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 07:00:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  62.5MB/s    in 1.1s
#
# 2024-03-25 07:00:28 (62.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7590   1802.04346v1  Interpretable machine learning models have rec...    cs
# 1569   1709.00155v1  Generating texts from structured data (e.g., a...    cs
# 3530   1711.03654v1  Obtaining detailed and reliable data about loc...  stat
# 3395   1611.00838v3  We consider the problem of consistently matchi...  stat
# 4578    1110.5667v1  This report outlines an approach to learning g...    cs
# ...             ...                                                ...   ...
# 1102   1709.04054v3  We propose a simple extension to the ReLU-fami...  stat
# 5351    1301.7411v1  In this paper we investigate the geometry of t...    cs
# 22739  1705.07832v1  Dropout is used as a practical tool to obtain ...  stat
# 29048  1708.02973v2  Visual object tracking is a fundamental and ti...    cs
# 11225  1504.05880v1  Kernel methods are an extremely popular set of...  stat
#
#                                                    title  year  \
# 7590   Hybrid Decision Making: When Interpretable Mod...  2018
# 1569   Order-Planning Neural Text Generation From Str...  2017
# 3530   Poverty Prediction with Public Landsat 7 Satel...  2017
# 3395   Initialization and Coordinate Optimization for...  2016
# 4578   Inducing Probabilistic Programs by Bayesian Pr...  2011
# ...                                                  ...   ...
# 1102   Shifting Mean Activation Towards Zero with Bip...  2017
# 5351   On the Geometry of Bayesian Graphical Models w...  2013
# 22739                                   Concrete Dropout  2017
# 29048  Learning Policies for Adaptive Tracking with D...  2017
# 11225  Spectral Norm of Random Kernel Matrices with A...  2015
#
#                                                 keywords
# 7590   [interpretable, increasing, especially, perfor...
# 1569   [generating, structured, important, processing...
# 3530   [obtaining, livelihoods, developing, countries...
# 3395   [consistently, underlying, objective, approxim...
# 4578   [generative, probabilistic, extension, algebra...
# ...                                                  ...
# 1102   [extension, activation, functions, activation,...
# 5351   [investigate, likelihood, parameters, variable...
# 22739  [practical, uncertainty, estimates, reinforcem...
# 29048  [fundamental, correlation, performance, fundam...
# 11225  [extremely, techniques, important, application...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7590     [interpretable, increasing, especially, perfor...
# 1569     [generating, structured, important, processing...
# 3530     [obtaining, livelihoods, developing, countries...
# 3395     [consistently, underlying, objective, approxim...
# 4578     [generative, probabilistic, extension, algebra...
#                                ...
# 6110     [considers, relationships, represented, dissim...
# 8275     [challenging, classification, recognizing, syn...
# 27845    [representation, potential, compressive, recon...
# 22877    [regression, interactions, arbitrary, predicto...
# 6235     [reputation, understand, intermediate, consequ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4665 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="30d922b1-0697-44b8-8d5f-ff5b49cbf666" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30d922b1-0697-44b8-8d5f-ff5b49cbf666")) {                    Plotly.newPlot(                        "30d922b1-0697-44b8-8d5f-ff5b49cbf666",                        [{"x":["performance","introduce","percentage","efficient","unsatisfying","objective","collaborative","inevitable","interpretable","improving","computation","strategies","interpretability","activated","theoretically","generated","experiments","complexity","performing","framework","preserving","explainability","otherwise","integrates","considers","algorithm","especially","increasing","predictive","explanations","practitioners","principled","baselines","satisfied","collaborate","typically","mentioned","generation","nationality","approaches","answering","structured","important","relationship","significantly","different","researchers","biography","conducted","generating","processing","frameworks","obtaining","developing","multispectral","consequently","expensive","relatively","frequently","accuracies","benchmarks","prediction","available","satellite","collected","resolution","countries","benchmark","optimizes","consistently","reasonable","initialization","initializing","empirical","coordinate","outperforms","optimization","permutation","alignment","information","assumptions","undirected","successfully","guarantees","empirically","underlying","approximate","probability","including","transformation","recursion","generates","abstraction","incrementally","induction","motivated","generalization","probabilistic","demonstrate","simplifies","extension","explanatory","generative","transformations","parameterized","algebraic","posterior","functions","stochastic","abstractions","arguments","achieving","methodological","keypoints","invariant","detection","practical","introduced","affecting","implementation","assumption","numerical","stability","sufficiently","extracted","detectors","inefficient","asymmetric","applications","implications","detections","invariance","importance","validations","datapoints","naturally","reduction","characteristics","distribution","estimates","distributions","structure","convergence","competitive","coordinates","investigate","underline","hindsight","techniques","selecting","algorithmic","scenarios","clustering","expectation","preferences","criterion","recommendations","automatically","computational","calibrate","algorithms","supervised","maximization","presented","estimation","representation","potentials","inference","iterations","gradually","potential","variables","circumventing","propagation","essentially","manipulating","application","statistical","limitation","instances","densities","neighbors","syntactic","phylogenetic","knowledge","geographic","scientific","databases","semantics","typological","existence","inventory","translation","exploiting","representations","translate","specifications","phonological","languages","incorporating"],"y":[881,370,14,419,2,151,37,5,31,94,144,113,18,6,43,174,565,225,75,571,50,2,20,24,43,834,122,89,74,16,19,35,68,12,4,102,14,139,2,410,46,78,352,74,281,748,78,2,68,90,303,31,46,61,7,29,64,53,26,25,99,244,289,17,84,122,6,200,10,40,34,37,6,140,25,264,336,11,41,716,73,8,87,50,67,113,112,174,276,50,7,56,22,18,25,61,117,184,552,10,89,5,116,45,21,15,44,223,128,9,26,80,4,10,63,355,115,121,11,124,71,87,36,20,133,36,11,16,394,34,19,32,76,2,3,49,100,78,233,95,117,364,113,119,15,148,2,0,383,45,30,90,159,37,39,46,20,190,298,1,549,221,36,199,200,368,11,217,33,19,156,139,1,76,17,9,226,174,18,115,15,29,51,4,350,6,37,55,92,3,38,7,105,75,256,16,13,5,102,59],"type":"bar"},{"x":["performance","introduce","percentage","efficient","unsatisfying","obje ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4665,), (4665, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.46067415730337075);'>Evaluating</span> <span style=''>Informal</span> <span style=''>Domain</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.4104683195592287);'>Representations</span> <span style=''>With</span> <span style=''>UrbanDictionary</span> <br/><br/><span style=''>Existing</span> <span style=''>corpora</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.39285714285714285);'>evaluation</span> <span style=''>are</span> <span style=''>not</span> <span style=''>targeted</span> <span style=''>towards</span> <span style=''>tasks</span> <span style=''>in</span> <span style=''>informal</span> <span style=''>domains</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Twitter</span> <span style=''>or</span> <span style=''>news</span> <span style=''>comment</span> <span style=''>forums</span> <span style=''>We</span> <span style=''>want</span> <span style=''>to</span> <span style=''>test</span> <span style=''>whether</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.41538461538461546);'>representation</span> <span style=''>of</span> <span style=''>informal</span> <span style=''>words</span> <span style=''>fulfills</span> <span style=''>the</span> <span style=''>promise</span> <span style=''>of</span> <span style=''>eliding</span> <span style=''>explicit</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalization</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>preprocessing</span> <span style=''>step</span> <span style=''>One</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.39285714285714285);'>evaluation</span> <span style=''>metric</span> <span style=''>for</span> <span style=''>such</span> <span style=''>domains</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proximity</span> <span style=''>of</span> <span style=''>spelling</span> <span style=''>variants</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>how</span> <span style=''>such</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>might</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>and</span> <span style=''>how</span> <span style=''>a</span> <span style=''>spelling</span> <span style=''>variant</span> <span style=''>dataset</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>collected</span> <span style=''>using</span> <span style=''>UrbanDictionary</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>One</span> <span style=''>Shot</span> <span style=''>Coresets</span> <span style=''>The</span> <span style=''>Case</span> <span style=''>of</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>Scaling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>massive</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>task</span> <span style=''>Recently</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>based</span> <span style=''>on</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarization</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>coresets</span> <span style=''>and</span> <span style=''>sketches</span> <span style=''>were</span> <span style=''>proposed</span> <span style=''>While</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>provide</span> <span style=''>provably</span> <span style=''>good</span> <span style=''>and</span> <span style=''>small</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summaries</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inherently</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practitioner</span> <span style=''>has</span> <span style=''>to</span> <span style=''>commit</span> <span style=''>to</span> <span style=''>a</span> <span style=''>fixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>before</span> <span style=''>even</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploring</span> <span style=''>the</span> <span style=''>data</span> <span style=''>However</span> <span style=''>can</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>small</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summaries</span> <span style=''>for</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>affirmatively</span> <span style=''>answer</span> <span style=''>this</span> <span style=''>question</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proposing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructs</span> <span style=''>such</span> <span style=''>one</span> <span style=''>shot</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summaries</span> <span style=''>for</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problems</span> <span style=''>while</span> <span style='background-color:rgba(255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Quadrature</span> <span style=''>based</span> <span style=''>features</span> <span style=''>for</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improving</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style=''>feature</span> <span style=''>maps</span> <span style=''>These</span> <span style=''>maps</span> <span style=''>arise</span> <span style=''>as</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>integral</span> <span style='background-color:rgba(0, 255, 0, 0.4104683195592287);'>representations</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>scale</span> <span style=''>up</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>larger</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3851590106007066);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.35294117647058815);'>integration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrals</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>methods</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3101555352241537);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>integrand</span> <span style=''>to</span> <span style=''>enhance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>facilitates</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.35057471264367807);'>convergence</span> <span style=''>behavior</span> <span style=''>and</span> <span style=''>conduct</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>study</span> <span style=''>that</span> <span style=''>supports</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Deformable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>which</span> <span style=''>do</span> <span style=''>not</span> <span style=''>modify</span> <span style=''>the</span> <span style=''>object</span> <span style=''>class</span> <span style=''>pose</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>could</span> <span style=''>be</span> <span style=''>rigid</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>non</span> <span style=''>rigid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deformable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>where</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>object</span> <span style=''>image</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instantiation</span> <span style=''>is</span> <span style=''>computed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separately</span> <span style=''>for</span> <span style=''>each</span> <span style=''>class</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>outputs</span> <span style=''>for</span> <span style=''>each</span> <span style=''>class</span> <span style=''>after</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>are</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>yield</span> <span style=''>the</span> <span style=''>final</span> <span style=''>decision</span> <span style=''>As</span> <span style=''>a</span> <span style=''>by</span> <span style=''>product</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>this</span> <span style=''>yields</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>object</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style=''>pose</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08676945141627823)
# 	knowledge (0.1254930082466834)
# 	segmentation (0.07135173897454285)
# 	representation (0.13194693438508426)
# 	information (0.2567228397275009)
# 	experimental (0.14772319827895303)
# 	detection (0.1272857655073503)
# 	different (0.2681964861957691)
# 	recognition (0.13911796342775187)
# 	convolutional (0.14772319827895303)
#
# Some Statistics words are:
# 	stochastic (0.13127797115862755)
# 	variables (0.1427150671307807)
# 	theoretical (0.14917951268025859)
# 	statistical (0.1581302834410741)
# 	distribution (0.18100447538538042)
# 	algorithm (0.3983092988562904)
# 	estimation (0.17155643958229735)
# 	inference (0.1879661859771258)
# 	regression (0.16907011437095973)
# 	dimensional (0.19393336648433615)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96fde6dd-0c7d-4321-82ca-f7b5f6187249" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96fde6dd-0c7d-4321-82ca-f7b5f6187249")) {                    Plotly.newPlot(                        "96fde6dd-0c7d-4321-82ca-f7b5f6187249",                        [{"x":["performance","introduce","percentage","efficient","unsatisfying","objective","collaborative","inevitable","interpretable","improving","computation","strategies","interpretability","activated","theoretically","generated","experiments","complexity","performing","framework","preserving","explainability","otherwise","integrates","considers","algorithm","especially","increasing","predictive","explanations","practitioners","principled","baselines","satisfied","collaborate","typically","mentioned","generation","nationality","approaches","answering","structured","important","relationship","significantly","different","researchers","biography","conducted","generating","processing","frameworks","obtaining","developing","multispectral","consequently","expensive","relatively","frequently","accuracies","benchmarks","prediction","available","satellite","collected","resolution","countries","benchmark","optimizes","consistently","reasonable","initialization","initializing","empirical","coordinate","outperforms","optimization","permutation","alignment","information","assumptions","undirected","successfully","guarantees","empirically","underlying","approximate","probability","including","transformation","recursion","generates","abstraction","incrementally","induction","motivated","generalization","probabilistic","demonstrate","simplifies","extension","explanatory","generative","transformations","parameterized","algebraic","posterior","functions","stochastic","abstractions","arguments","achieving","methodological","keypoints","invariant","detection","practical","introduced","affecting","implementation","assumption","numerical","stability","sufficiently","extracted","detectors","inefficient","asymmetric","applications","implications","detections","invariance","importance","validations","datapoints","naturally","reduction","characteristics","distribution","estimates","distributions","structure","convergence","competitive","coordinates","investigate","underline","hindsight","techniques","selecting","algorithmic","scenarios","clustering","expectation","preferences","criterion","recommendations","automatically","computational","calibrate","algorithms","supervised","maximization","presented","estimation","representation","potentials","inference","iterations","gradually","potential","variables","circumventing","propagation","essentially","manipulating","application","statistical","limitation","instances","densities","neighbors","syntactic","phylogenetic","knowledge","geographic","scientific","databases","semantics","typological","existence","inventory","translation","exploiting","representations","translate","specifications","phonological","languages","incorporating","resulting","likelihood","differentiable","replacing","minimizing","minimized","procedure","simulators","tractable","increasingly","experimental","parameters","producing","observations","synthetic","continuous","wasserstein","difficult","simulator","adversarial","variational","objectives","effectively","successful","implement","developed","heuristic","scheduling","evolutionary","situations","combining","precedence","solutions","technique","operators","mathematically","polynomial","combinatorial","approximation","constraints","stochastically","classification","contamination","conditions","characterized","associated","sufficient","identifiability","combinations","arbitrary","membership","multiclass","assignments","threshold","poster ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hindsight
# 	contamination
# 	cumulants
# 	generalisations
# 	majorizer
# 	undersampled
# 	elucidate
# 	nesterovs
# 	presupposes
# 	diarization
# 	interfacing
# 	fmathcalx
# 	varepsilon
# 	recombine
# 	validator
# 	hippocampal
# 	correspondingly
# 	schizophrenia
# 	universality
# 	sparsifies
# Some words which never appear in Statistics papers:
# 	nationality
# 	biography
# 	abstractions
# 	keypoints
# 	syntactic
# 	typological
# 	specifications
# 	phonological
# 	requested
# 	vagueness
# 	participate
# 	complying
# 	explicitness
# 	nonmonotonic
# 	propositional
# 	rectangular
# 	excellence
# 	portability
# 	productivity
# 	extractors

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0717247734602984e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
